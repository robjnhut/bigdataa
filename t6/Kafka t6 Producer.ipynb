# %%
# Install PySpark (latest version as of May 2025 is 3.5.5)
# !pip install pyspark==3.5.5

# Install Kafka-Python
# !pip install kafka-python
# Out:
# Requirement already satisfied: pyspark==3.5.5 in c:\users\hii\appdata\local\programs\python\python312\lib\site-packages (3.5.5)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\hii\appdata\local\programs\python\python312\lib\site-packages (from pyspark==3.5.5) (0.10.9.7)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: kafka-python in c:\users\hii\appdata\local\programs\python\python312\lib\site-packages (2.2.6)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kafka import KafkaProducer
from json import dumps
from time import sleep
import random

# Configure the producer
topic_name = 'RandomNumber'
kafka_server = 'localhost:9092'
producer = KafkaProducer(
    bootstrap_servers=kafka_server,
    value_serializer=lambda x: dumps(x).encode('utf-8')
)

# Send data
print("Starting to send data to Kafka topic:", topic_name)
for e in range(1000):
    # Generate random number between 0-100
    number = random.randint(0, 100)
    data = {'number': number}
    producer.send(topic_name, value=data)
    print(f"Sent: {data}")
    sleep(5)  # Send a new number every 5 seconds

producer.flush()
# Out:
# Starting to send data to Kafka topic: RandomNumber
# Sent: {'number': 6}
# Sent: {'number': 25}
# Sent: {'number': 29}
# Sent: {'number': 48}
# Sent: {'number': 33}
# Sent: {'number': 84}
# Sent: {'number': 61}
# Sent: {'number': 53}
# Sent: {'number': 23}
# Sent: {'number': 6}
# Sent: {'number': 2}
# Sent: {'number': 52}
# Sent: {'number': 67}
# Sent: {'number': 30}
# Sent: {'number': 84}
# Sent: {'number': 43}
# Sent: {'number': 38}
# Sent: {'number': 11}
# Sent: {'number': 13}
# Sent: {'number': 93}
# Sent: {'number': 97}
# Sent: {'number': 75}
# Sent: {'number': 33}
# Sent: {'number': 13}
# Sent: {'number': 93}
# Sent: {'number': 7}
# Sent: {'number': 15}
# Sent: {'number': 92}
# Sent: {'number': 57}
# Sent: {'number': 36}
# Sent: {'number': 71}
# Sent: {'number': 87}
# Sent: {'number': 7}
# Sent: {'number': 24}
# Sent: {'number': 87}
# Sent: {'number': 96}
# Sent: {'number': 89}
# Sent: {'number': 90}
# Sent: {'number': 48}
# Sent: {'number': 84}
# Sent: {'number': 95}
# Sent: {'number': 60}
# Sent: {'number': 66}
# Sent: {'number': 43}
# Sent: {'number': 44}
# Sent: {'number': 41}
# Sent: {'number': 27}
# Sent: {'number': 63}
# Sent: {'number': 47}
# Sent: {'number': 5}
# Sent: {'number': 35}
# Sent: {'number': 6}
# Sent: {'number': 68}
# Sent: {'number': 30}
# Sent: {'number': 22}
# Sent: {'number': 24}
# Sent: {'number': 4}
# Sent: {'number': 80}
# Sent: {'number': 42}
# Sent: {'number': 53}
# Sent: {'number': 42}
# Sent: {'number': 26}
# Sent: {'number': 15}
# Sent: {'number': 94}
# Sent: {'number': 46}
# Sent: {'number': 14}
# Sent: {'number': 10}
# Sent: {'number': 43}
# Sent: {'number': 18}
# Sent: {'number': 61}
# Sent: {'number': 42}
# Sent: {'number': 70}
# Sent: {'number': 81}
# Sent: {'number': 61}
# Sent: {'number': 57}
# Sent: {'number': 79}
# Sent: {'number': 12}
# Sent: {'number': 74}
# Sent: {'number': 29}
# Sent: {'number': 11}
# Sent: {'number': 5}
# Sent: {'number': 61}
# Sent: {'number': 80}
# Sent: {'number': 9}
# Sent: {'number': 11}
# Sent: {'number': 91}
# Sent: {'number': 6}
# Sent: {'number': 48}
# Sent: {'number': 38}
# Sent: {'number': 37}
# Sent: {'number': 58}
# Sent: {'number': 88}
# Sent: {'number': 94}
# Sent: {'number': 83}
# Sent: {'number': 97}
# Sent: {'number': 39}
# Sent: {'number': 48}
# Sent: {'number': 49}
# Sent: {'number': 28}
# Sent: {'number': 30}
# Sent: {'number': 58}
# Sent: {'number': 89}
# Sent: {'number': 64}
# Sent: {'number': 13}
# Sent: {'number': 96}
# Sent: {'number': 44}
# Sent: {'number': 19}
# Sent: {'number': 52}
# Sent: {'number': 7}
# Sent: {'number': 87}
# Sent: {'number': 60}
# Sent: {'number': 7}
# Sent: {'number': 77}
# Sent: {'number': 99}
# Sent: {'number': 33}
# Sent: {'number': 28}
# Sent: {'number': 61}
# Sent: {'number': 36}
# Sent: {'number': 35}
# Sent: {'number': 88}
# Sent: {'number': 16}
# Sent: {'number': 94}
# Sent: {'number': 92}
# Sent: {'number': 4}
# Sent: {'number': 12}
# Sent: {'number': 46}
# Sent: {'number': 90}
# Sent: {'number': 67}
# Sent: {'number': 2}
# Sent: {'number': 57}
# Sent: {'number': 74}
# Sent: {'number': 69}
# Sent: {'number': 31}
# Sent: {'number': 46}
# Sent: {'number': 0}
# Sent: {'number': 7}
# Sent: {'number': 89}
# Sent: {'number': 13}
# Sent: {'number': 68}
# Sent: {'number': 62}
# Sent: {'number': 83}
# Sent: {'number': 41}
# Sent: {'number': 76}
# Sent: {'number': 72}
# Sent: {'number': 73}
# Sent: {'number': 52}
# Sent: {'number': 89}
# Sent: {'number': 85}
# Sent: {'number': 59}
# Sent: {'number': 53}
# Sent: {'number': 83}
# Sent: {'number': 66}
# Sent: {'number': 85}
# Sent: {'number': 1}
# Sent: {'number': 80}
# Sent: {'number': 94}
# Sent: {'number': 82}
# Sent: {'number': 30}
# Sent: {'number': 11}
# Sent: {'number': 21}
# Sent: {'number': 44}
# Sent: {'number': 30}
# Sent: {'number': 75}
# Sent: {'number': 50}
# Sent: {'number': 87}
# Sent: {'number': 60}
# Sent: {'number': 78}
# Sent: {'number': 81}
# Sent: {'number': 93}
# Sent: {'number': 24}
# Sent: {'number': 81}
# Sent: {'number': 46}
# Sent: {'number': 16}
# Sent: {'number': 46}
# Sent: {'number': 11}
# Sent: {'number': 0}
# Sent: {'number': 57}
# Sent: {'number': 38}
# Sent: {'number': 32}
# Sent: {'number': 91}
# Sent: {'number': 81}
# Sent: {'number': 31}
# Sent: {'number': 89}
# Sent: {'number': 46}
# Sent: {'number': 99}
# Sent: {'number': 66}
# Sent: {'number': 64}
# Sent: {'number': 19}
# Sent: {'number': 11}
# Sent: {'number': 16}
# Sent: {'number': 37}
# Sent: {'number': 37}
# Sent: {'number': 70}
# Sent: {'number': 86}
# Sent: {'number': 9}
# Sent: {'number': 7}
# Sent: {'number': 12}
# Sent: {'number': 93}
# Sent: {'number': 23}
# Sent: {'number': 23}
# Sent: {'number': 96}
# Sent: {'number': 76}
# Sent: {'number': 62}
# Sent: {'number': 6}
# Sent: {'number': 11}
# Sent: {'number': 41}
# Sent: {'number': 2}
# Sent: {'number': 61}
# Sent: {'number': 33}
# Sent: {'number': 42}
# Sent: {'number': 7}
# Sent: {'number': 75}
# Sent: {'number': 66}
# Sent: {'number': 61}
# Sent: {'number': 35}
# Sent: {'number': 56}
# Sent: {'number': 82}
# Sent: {'number': 60}
# Sent: {'number': 55}
# Sent: {'number': 31}
# Sent: {'number': 31}
# Sent: {'number': 72}
# Sent: {'number': 62}
# Sent: {'number': 50}
# Sent: {'number': 31}
# Sent: {'number': 26}
# Sent: {'number': 22}
# Sent: {'number': 19}
# Sent: {'number': 14}
# Sent: {'number': 88}
# Sent: {'number': 61}
# Sent: {'number': 35}
# Sent: {'number': 89}
# Sent: {'number': 25}
# Sent: {'number': 3}
# Sent: {'number': 28}
# Sent: {'number': 77}
# Sent: {'number': 43}
# Sent: {'number': 92}
# Sent: {'number': 26}
# Sent: {'number': 77}
# Sent: {'number': 19}
# Sent: {'number': 4}
# Sent: {'number': 84}
# Sent: {'number': 10}
# Sent: {'number': 96}
# Sent: {'number': 47}
# Sent: {'number': 19}
# Sent: {'number': 41}
# Sent: {'number': 74}
# Sent: {'number': 13}
# Sent: {'number': 79}
# Sent: {'number': 3}
# Sent: {'number': 98}
# Sent: {'number': 0}
# Sent: {'number': 41}
# Sent: {'number': 95}
# Sent: {'number': 51}
# Sent: {'number': 39}
# Sent: {'number': 66}
# Sent: {'number': 91}
# Sent: {'number': 66}
# Sent: {'number': 79}
# Sent: {'number': 35}
# Sent: {'number': 80}
# Sent: {'number': 3}
# Sent: {'number': 41}
# Sent: {'number': 8}
# Sent: {'number': 72}
# Sent: {'number': 6}
# Sent: {'number': 98}
# Sent: {'number': 75}
# Sent: {'number': 20}
# Sent: {'number': 30}
# Sent: {'number': 7}
# Sent: {'number': 13}
# Sent: {'number': 67}
# Sent: {'number': 22}
# Sent: {'number': 38}
# Sent: {'number': 37}
# Sent: {'number': 74}
# Sent: {'number': 17}
# Sent: {'number': 50}
# Sent: {'number': 94}
# Sent: {'number': 19}
# Sent: {'number': 16}
# Sent: {'number': 30}
# Sent: {'number': 3}
# Sent: {'number': 4}
# Sent: {'number': 93}
# Sent: {'number': 77}
# Sent: {'number': 96}
# Sent: {'number': 53}
# Sent: {'number': 91}
# Sent: {'number': 91}
# Sent: {'number': 87}
# Sent: {'number': 34}
# Sent: {'number': 51}
# Sent: {'number': 78}
# Sent: {'number': 20}
# Sent: {'number': 80}
# Sent: {'number': 24}
# Sent: {'number': 80}
# Sent: {'number': 41}
# Sent: {'number': 85}
# Sent: {'number': 80}
# Sent: {'number': 72}
# Sent: {'number': 11}
# Sent: {'number': 50}
# Sent: {'number': 4}
# Sent: {'number': 12}
# Sent: {'number': 70}
# Sent: {'number': 53}
# Sent: {'number': 71}
# Sent: {'number': 84}
# Sent: {'number': 91}
# Sent: {'number': 44}
# Sent: {'number': 97}
# Sent: {'number': 96}
# Sent: {'number': 49}
# Sent: {'number': 51}
# Sent: {'number': 29}
# Sent: {'number': 16}
# Sent: {'number': 50}
# Sent: {'number': 84}
# Sent: {'number': 17}
# Sent: {'number': 90}
# Sent: {'number': 40}
# Sent: {'number': 20}
# Sent: {'number': 65}
# Sent: {'number': 91}
# Sent: {'number': 34}
# Sent: {'number': 61}
# Sent: {'number': 85}
# Sent: {'number': 55}
# Sent: {'number': 80}
# Sent: {'number': 50}
# Sent: {'number': 45}
# Sent: {'number': 52}
# Sent: {'number': 33}
# Sent: {'number': 3}
# Sent: {'number': 4}
# Sent: {'number': 19}
# Sent: {'number': 33}
# Sent: {'number': 63}
# Sent: {'number': 69}
# Sent: {'number': 97}
# Sent: {'number': 21}
# Sent: {'number': 42}
# Sent: {'number': 40}
# Sent: {'number': 43}
# Sent: {'number': 20}
# Sent: {'number': 72}
# Sent: {'number': 86}
# Sent: {'number': 88}
# Sent: {'number': 9}
# Sent: {'number': 7}
# Sent: {'number': 60}
# Sent: {'number': 44}
# Sent: {'number': 55}
# Sent: {'number': 26}
# Sent: {'number': 22}
# Sent: {'number': 63}
# Sent: {'number': 30}
# Sent: {'number': 43}
# Sent: {'number': 15}
# Sent: {'number': 47}
# Sent: {'number': 98}
# Sent: {'number': 79}
# Sent: {'number': 32}
# Sent: {'number': 63}
# Sent: {'number': 68}
# Sent: {'number': 68}
# Sent: {'number': 21}
# Sent: {'number': 95}
# Sent: {'number': 26}
# Sent: {'number': 74}
# Sent: {'number': 54}
# Sent: {'number': 91}
# Sent: {'number': 1}
# Sent: {'number': 61}
# Sent: {'number': 33}
# Sent: {'number': 12}
# Sent: {'number': 56}
# Sent: {'number': 71}
# Sent: {'number': 39}
# Sent: {'number': 60}
# Sent: {'number': 37}
# Sent: {'number': 40}
# Sent: {'number': 57}
# Sent: {'number': 89}
# Sent: {'number': 6}
# Sent: {'number': 16}
# Sent: {'number': 39}
# Sent: {'number': 17}
# Sent: {'number': 56}
# Sent: {'number': 37}
# Sent: {'number': 40}
# Sent: {'number': 52}
# Sent: {'number': 84}
# Sent: {'number': 59}
# Sent: {'number': 22}
# Sent: {'number': 89}
# Sent: {'number': 56}
# Sent: {'number': 50}
# Sent: {'number': 23}
# Sent: {'number': 75}
# Sent: {'number': 42}
# Sent: {'number': 53}
# Sent: {'number': 72}
# Sent: {'number': 45}
# Sent: {'number': 96}
# Sent: {'number': 25}
# Sent: {'number': 33}
# Sent: {'number': 84}
# Sent: {'number': 75}
# Sent: {'number': 51}
# Sent: {'number': 75}
# Sent: {'number': 46}
# Sent: {'number': 71}
# Sent: {'number': 68}
# Sent: {'number': 65}
# Sent: {'number': 1}
# Sent: {'number': 85}
# Sent: {'number': 86}
# Sent: {'number': 73}
# Sent: {'number': 22}
# Sent: {'number': 11}
# Sent: {'number': 5}
# Sent: {'number': 20}
# Sent: {'number': 70}
# Sent: {'number': 19}
# Sent: {'number': 83}
# Sent: {'number': 23}
# Sent: {'number': 90}
# Sent: {'number': 84}
# Sent: {'number': 53}
# Sent: {'number': 87}
# Sent: {'number': 99}
# Sent: {'number': 0}
# Sent: {'number': 9}
# Sent: {'number': 1}
# Sent: {'number': 45}
# Sent: {'number': 19}
# Sent: {'number': 86}
# Sent: {'number': 56}
# Sent: {'number': 47}
# Sent: {'number': 66}
# Sent: {'number': 76}
# Sent: {'number': 75}
# Sent: {'number': 1}
# Sent: {'number': 56}
# Sent: {'number': 63}
# Sent: {'number': 27}
# Sent: {'number': 87}
# Sent: {'number': 20}
# Sent: {'number': 36}
# Sent: {'number': 95}
# Sent: {'number': 13}
# Sent: {'number': 32}
# Sent: {'number': 1}
# Sent: {'number': 70}
# Sent: {'number': 44}
# Sent: {'number': 39}
# Sent: {'number': 96}
# Sent: {'number': 16}
# Sent: {'number': 27}
# Sent: {'number': 67}
# Sent: {'number': 39}
# Sent: {'number': 66}
# Sent: {'number': 7}
# Sent: {'number': 62}
# Sent: {'number': 7}
# Sent: {'number': 14}
# Sent: {'number': 99}
# Sent: {'number': 35}
# Sent: {'number': 15}
# Sent: {'number': 36}
# Sent: {'number': 15}
# Sent: {'number': 5}
# Sent: {'number': 16}
# Sent: {'number': 25}
# Sent: {'number': 81}
# Sent: {'number': 39}
# Sent: {'number': 54}
# Sent: {'number': 24}
# Sent: {'number': 29}
# Sent: {'number': 8}
# Sent: {'number': 69}
# Sent: {'number': 38}
# Sent: {'number': 57}
# Sent: {'number': 10}
# Sent: {'number': 44}
# Sent: {'number': 24}
# Sent: {'number': 35}
# Sent: {'number': 45}
# Sent: {'number': 94}
# Sent: {'number': 11}
# Sent: {'number': 25}
# Sent: {'number': 74}
# Sent: {'number': 73}
# Sent: {'number': 49}
# Sent: {'number': 61}
# Sent: {'number': 84}
# Sent: {'number': 33}
# Sent: {'number': 24}
# Sent: {'number': 41}
# Sent: {'number': 15}
# Sent: {'number': 76}
# Sent: {'number': 68}
# Sent: {'number': 56}
# Sent: {'number': 39}
# Sent: {'number': 44}
# Sent: {'number': 55}
# Sent: {'number': 90}
# Sent: {'number': 73}
# Sent: {'number': 83}
# Sent: {'number': 71}
# Sent: {'number': 67}
# Sent: {'number': 2}
# Sent: {'number': 91}
# Sent: {'number': 77}
# Sent: {'number': 13}
# Sent: {'number': 41}
# Sent: {'number': 54}
# Sent: {'number': 18}
# Sent: {'number': 26}
# Sent: {'number': 50}
# Sent: {'number': 75}
# Sent: {'number': 36}
# Sent: {'number': 29}
# Sent: {'number': 24}
# Sent: {'number': 21}
# Sent: {'number': 100}
# Sent: {'number': 92}
# Sent: {'number': 10}
# Sent: {'number': 28}
# Sent: {'number': 10}
# Sent: {'number': 69}
# Sent: {'number': 1}
# Sent: {'number': 43}
# Sent: {'number': 100}
# Sent: {'number': 59}
# Sent: {'number': 96}
# Sent: {'number': 83}
# Sent: {'number': 73}
# Sent: {'number': 53}
# Sent: {'number': 3}
# Sent: {'number': 66}
# Sent: {'number': 88}
# Sent: {'number': 84}
# Sent: {'number': 17}
# Sent: {'number': 40}
# Sent: {'number': 38}
# Sent: {'number': 17}
# Sent: {'number': 29}
# Sent: {'number': 23}
# Sent: {'number': 23}
# Sent: {'number': 29}
# Sent: {'number': 29}
# Sent: {'number': 86}
# Sent: {'number': 5}
# Sent: {'number': 0}
# Sent: {'number': 97}
# Sent: {'number': 4}
# Sent: {'number': 85}
# Sent: {'number': 24}
# Sent: {'number': 45}
# Sent: {'number': 48}
# Sent: {'number': 61}
# Sent: {'number': 57}
# Sent: {'number': 21}
# Sent: {'number': 29}
# Sent: {'number': 47}
# Sent: {'number': 2}
# Sent: {'number': 18}
# Sent: {'number': 76}
# Sent: {'number': 54}
# Sent: {'number': 4}
# Sent: {'number': 13}
# Sent: {'number': 66}
# Sent: {'number': 23}
# Sent: {'number': 55}
# Sent: {'number': 82}
# Sent: {'number': 5}
# Sent: {'number': 71}
# Sent: {'number': 15}
# Sent: {'number': 17}
# Sent: {'number': 24}
# Sent: {'number': 45}
# Sent: {'number': 98}
# Sent: {'number': 10}
